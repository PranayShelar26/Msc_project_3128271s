# %% [markdown]
# # Cross-Architecture Energy Prediction — Data Processing Pipeline
#
# This notebook loads and processes traces from two sources:
# - **Lotaru** (7 machines, runtime + memory only, no energy)
# - **Augur** (4 gpgnodes, runtime + memory + RAPL energy)
#
# and builds task-level energy attributions from raw RAPL package/DRAM counters.

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Configuration

# %%
LOTARU_BASE_URL = "https://raw.githubusercontent.com/CRC-FONDA/Lotaru-traces/master/traces"

MACHINE_FOLDER_MAP = {
    "a1":          "asok01",
    "a2":          "asok02",
    "c2":          "c2",
    "local":       "local",
    "localRedCpu": "wallyRedCpu",
    "n1":          "n1",
    "n2":          "n2",
}

WORKFLOWS = ["atacseq", "bacass", "chipseq", "eager", "methylseq"]

AUGUR_BASE_URL = "../augur/experiments"

# %% [markdown]
# ## 3. Lotaru Data Loading

# %%
def load_lotaru():
    frames = []
    for machine_name, folder_name in MACHINE_FOLDER_MAP.items():
        for workflow in WORKFLOWS:
            url = f"{LOTARU_BASE_URL}/{machine_name}/results_{workflow}/execution_report_{folder_name}.csv"
            try:
                df = pd.read_csv(url)
            except Exception as e:
                print(f"SKIP {machine_name}/{workflow}: {e}")
                continue
            df["source_machine"] = machine_name
            df["source_workflow"] = workflow   # FIXED — was folder_name
            frames.append(df)

    return pd.concat(frames, ignore_index=True)

# %%
lotaru_df = load_lotaru()
print(lotaru_df["source_machine"].value_counts())
print(lotaru_df["source_workflow"].value_counts())
# Out:
# source_machine
# a1             1501
# a2             1501
# c2             1501
# n2             1501
# n1             1487
# local          1333
# localRedCpu    1333
# Name: count, dtype: int64
# source_workflow
# chipseq      3450
# atacseq      2422
# eager        2262
# methylseq    1253
# bacass        770
# Name: count, dtype: int64

# %%
lotaru_df.to_csv("../Processed_data/lotaru_traces.csv",index=False)

# %% [markdown]
# ## 4. Energy Processing — Raw RAPL Counters
#
# Cluster-specific RAPL constants (gu-cluster is dual-socket with `energy_1`/`energy_2`; hu-cluster is single-socket with one `energy` column, different wraparound values). Empty DRAM files fall back to package-only energy. Jitter intervals above a plausible-watt ceiling are nulled.

# %%
ENERGY_UNIT_DIVISOR = 1_000_000  # verified against the actual RAPL logging tool's units
RAPL_CONSTRAINTS = {
    "gu-cluster": {"pkg": 65532610987,  "dram": 65532610987},
    "hu-cluster": {"pkg": 262143328850, "dram": 65712999613},
}

PLAUSIBLE_MAX_WATTS = {
    "gu-cluster": 300,
    "hu-cluster": 1000,
}
def load_energy_data(path, max_uj, max_watts):
    df = pd.read_csv(path)
    df = df.sort_values("timestamp").reset_index(drop=True)

    # Detect energy columns: gu-cluster has energy_1 + energy_2 (dual socket),
    # hu-cluster has a single 'energy' column (single socket).
    energy_cols = [c for c in df.columns if c.startswith("energy")]

    total_delta = 0
    for col in energy_cols:
        delta = df[col].diff()
        wrapped = delta < 0
        delta.loc[wrapped] = delta.loc[wrapped] + max_uj
        total_delta = total_delta + delta

    df["interval_j"] = total_delta / ENERGY_UNIT_DIVISOR
    df["time_gap_s"] = df["timestamp"].diff() / 1000
    df["implied_watts"] = df["interval_j"] / df["time_gap_s"]

    suspect = df["implied_watts"] > max_watts
    df.loc[suspect, "interval_j"] = None
    return df

# %%
def load_node_energy(node, run, run_dir, cluster, verbose=True):
    consts = RAPL_CONSTRAINTS[cluster]
    max_watts = PLAUSIBLE_MAX_WATTS[cluster]

    pkg = load_energy_data(
        os.path.join(run_dir, "energy", f"run_{run}_{node}_pkg.csv"),
        max_uj=consts["pkg"], max_watts=max_watts,
    )

    # DRAM may be empty or missing on some nodes — fall back to pkg-only if so
    dram_path = os.path.join(run_dir, "energy", f"run_{run}_{node}_dram.csv")
    try:
        dram = load_energy_data(dram_path, max_uj=consts["dram"], max_watts=max_watts)
        if dram.empty or dram["interval_j"].notna().sum() == 0:
            raise ValueError("empty dram")
        merged = pd.merge_asof(
            pkg[["timestamp", "interval_j"]],
            dram[["timestamp", "interval_j"]],
            on="timestamp", direction="nearest", tolerance=50,
            suffixes=("_pkg", "_dram"),
        )
        merged["total_interval_j"] = merged["interval_j_pkg"] + merged["interval_j_dram"]
    except (ValueError, pd.errors.EmptyDataError, FileNotFoundError):
        if verbose:
            print(f"  {node}: DRAM missing/empty — using package energy only")
        merged = pkg[["timestamp", "interval_j"]].rename(columns={"interval_j": "total_interval_j"})

    return merged[["timestamp", "total_interval_j"]]

# %% [markdown]
# ## 5. Task-Level Energy Attribution

# %%
def task_energy(task_row, energy_by_host):
    hostname = task_row["hostname"]
    # Find the energy key that matches this hostname
    # (energy keys like 'c40' or 'gpgnode13'; hostnames like 'hu-worker-c40' or 'gpgnode-13')
    host = None
    for key in energy_by_host:
        if key.replace("-", "") in hostname.replace("-", ""):
            host = key
            break
    if host is None:
        return None

    host_energy = energy_by_host[host]
    window = host_energy[
        (host_energy["timestamp"] >= task_row["start"]) &
        (host_energy["timestamp"] <= task_row["complete"])
    ]
    if window.empty:
        return None
    return round(window["total_interval_j"].sum(), 4)

# %% [markdown]
# ## 6. Concurrency Feature
#
# Window-based energy includes concurrent tasks on the same node; this counts them per task (scoped within a run) so the model can account for it.

# %%
# Check for concurrent tasks on the same node during the long task's window
def check_concurrent_tasks(task_row,trace):
    overlapping= trace[
        (trace["hostname"] == task_row["hostname"]) &
        (trace["start"] < task_row["complete"]) &
        (trace["complete"] > task_row["start"]) &
        (trace["task_id"] != task_row["task_id"])
    ]
    
    return len(overlapping)

# %% [markdown]
# ## 7. Scale Across Clusters, Workflows, and Runs
#
# Runs the full pipeline over both clusters × 4 workflows × 3 runs, detecting nodes per run dynamically and tagging `source_cluster`.

# %%
import os

AUGUR_WORKFLOWS = ["atacseq", "chipseq", "nanoseq", "rnaseq"]
AUGUR_CLUSTERS = ["gu-cluster","hu-cluster"]
AUGUR_RUNS = ["1", "2", "3"]

def get_nodes_for_run(run_dir):
    energy_dir = os.path.join(run_dir, "energy")
    pkg_files = [f for f in os.listdir(energy_dir) if f.endswith("_pkg.csv")]
    return sorted(f.replace("_pkg.csv", "").split("_", 2)[2] for f in pkg_files)

def process_augur_run(workflow, run,cluster):
    run_dir = os.path.join(AUGUR_BASE_URL, cluster,workflow, run)

    # Load + filter trace
    trace = pd.read_csv(os.path.join(run_dir, "trace.csv"))
    trace = trace[trace["status"] == "COMPLETED"].copy()
    trace["start"] = trace["start"].astype(int)
    trace["complete"] = trace["complete"].astype(int)

    # Build energy_by_host for nodes that actually have energy files
    nodes = get_nodes_for_run(run_dir)
    energy_by_host = {}
    for node in nodes:
        try:
            energy_by_host[node] = load_node_energy(node, run,run_dir, cluster,verbose=False)
        except Exception as e:
            print(f"  energy load failed {workflow}/{run}/{node}: {e}")

    # Per-task energy + concurrency (concurrency scoped to THIS run only)
    trace["task_energy_j"] = trace.apply(lambda r: task_energy(r, energy_by_host), axis=1)
    trace["concurrent_task_count"] = trace.apply(lambda r: check_concurrent_tasks(r, trace), axis=1)
    trace["start"]= trace["start"].astype(int)
    trace["complete"]= trace["complete"].astype(int)
    trace["source_workflow"] = workflow
    trace["source_run"] = run
    trace["source_cluster"] = cluster
    for col in ["realtime", "peak_rss", "rchar", "cpus"]:
        trace[col] = pd.to_numeric(trace[col], errors="coerce")

    return trace

# Main loop
all_augur = []
for cluster in AUGUR_CLUSTERS:
    for wf in AUGUR_WORKFLOWS:
        for run in AUGUR_RUNS:
            try:
                df = process_augur_run(wf, run,cluster=cluster)
                all_augur.append(df)
                print(f"OK {wf}/{run}: {len(df)} tasks, {df['task_energy_j'].notna().sum()} with energy")
            except Exception as e:
                print(f"SKIP {wf}/{run}: {e}")

augur_all = pd.concat(all_augur, ignore_index=True)
print(f"\nTotal: {len(augur_all)} tasks across {augur_all['source_workflow'].nunique()} workflows")
# Out:
# OK atacseq/1: 268 tasks, 246 with energy
# OK atacseq/2: 268 tasks, 260 with energy
# OK atacseq/3: 268 tasks, 248 with energy
# OK chipseq/1: 314 tasks, 281 with energy
# OK chipseq/2: 314 tasks, 289 with energy
# OK chipseq/3: 314 tasks, 295 with energy
# OK nanoseq/1: 92 tasks, 89 with energy
# OK nanoseq/2: 92 tasks, 86 with energy
# OK nanoseq/3: 92 tasks, 91 with energy
# OK rnaseq/1: 231 tasks, 228 with energy
# OK rnaseq/2: 231 tasks, 225 with energy
# OK rnaseq/3: 231 tasks, 222 with energy
# OK atacseq/1: 268 tasks, 241 with energy
# OK atacseq/2: 268 tasks, 243 with energy
# OK atacseq/3: 268 tasks, 239 with energy
# OK chipseq/1: 3538 tasks, 3157 with energy
# OK chipseq/2: 3538 tasks, 3179 with energy
# OK chipseq/3: 3538 tasks, 3152 with energy
# OK nanoseq/1: 92 tasks, 86 with energy
# OK nanoseq/2: 92 tasks, 87 with energy
# OK nanoseq/3: 92 tasks, 86 with energy
# OK rnaseq/1: 1269 tasks, 1183 with energy
# OK rnaseq/2: 1269 tasks, 1187 with energy
# OK rnaseq/3: 1269 tasks, 1178 with energy
#
# Total: 18216 tasks across 4 workflows

# %%
print(f"Total: {len(augur_all)} tasks")
print(augur_all.groupby("source_cluster")["source_workflow"].value_counts())  # if you added source_cluster
# Out:
# Total: 18216 tasks
# source_cluster  source_workflow
# gu-cluster      chipseq              942
#                 atacseq              804
#                 rnaseq               693
#                 nanoseq              276
# hu-cluster      chipseq            10614
#                 rnaseq              3807
#                 atacseq              804
#                 nanoseq              276
# Name: count, dtype: int64

# %%
print(augur_all.groupby("source_cluster")["task_energy_j"].describe())
# Out:
#                   count          mean           std      min        25%  \
# source_cluster
# gu-cluster       2560.0  18810.041256  37882.950243   0.0000  1558.4675
# hu-cluster      14018.0  18276.957842  30849.557890  46.7687  1616.4967
#
#                        50%           75%          max
# source_cluster
# gu-cluster      6927.38900  19753.824925  471888.7077
# hu-cluster      6725.41935  23045.838850  752041.8269

# %%
# Out:
# [     task_id    hostname                                  native_id  \
# 0          3  gpgnode-14  nf-0e3803359c26a30cca1e0b195da315e6-1f3ad
# 1          2  gpgnode-15  nf-381b996c7b899bb63229f463b8fa6491-c18ae
# 2          4  gpgnode-16  nf-241fd911a3662f5f87f8dba19bd36843-a2520
# 3          6  gpgnode-15  nf-5d7df9583944c11978d04de45c496f6b-03d49
# 4          1  gpgnode-13  nf-4bbc03314ca4bd7ae2f1351d9c5441ae-c334b
# ..       ...         ...                                        ...
# 263      265  gpgnode-15  nf-5ee7bdbf0aedf8620501bfa79b42425b-15b1b
# 264      266  gpgnode-16  nf-319f0b57de5186490892a37e3d2438ba-12d22
# 265      257  gpgnode-14  nf-63a4be674cbbff721cb096688ac8af72-faf89
# 266      267  gpgnode-15  nf-ba8c84e9296780c9f44312b4d6057633-5ac9d
# 267      268  gpgnode-16  nf-0086bc4adfbb4cd25ba756015ed96785-42e08
#
#                                                process                   tag  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  samplesheet_full.csv
# 1        NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED             genes.gtf
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  GM12878_FAST_REP1_T1
# 3    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  GM12878_FAST_REP2_T1
# 4    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...             genome.fa
# ..                                                 ...                   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV                     -
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...                     -
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 267                     NFCORE_ATACSEQ:ATACSEQ:MULTIQC                     -
#
#                                                   name     status  exit  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  COMPLETED     0
# 3    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  COMPLETED     0
# 4    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# ..                                                 ...        ...   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV  COMPLETED     0
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...  COMPLETED     0
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 267                 NFCORE_ATACSEQ:ATACSEQ:MULTIQC (1)  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         3
# 1        -                  quay.io/biocontainers/perl:5.26.2  ...      1076
# 2        -             quay.io/biocontainers/fastqc:0.11.9--0  ...         9
# 3        -             quay.io/biocontainers/fastqc:0.11.9--0  ...        12
# 4        -  quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      1512
# ..     ...                                                ...  ...       ...
# 263      -                 quay.io/biocontainers/python:3.8.3  ...         1
# 264      -   quay.io/biocontainers/multiqc:1.14--pyhdfd78af_0  ...         3
# 265      -  quay.io/biocontainers/mulled-v2-8186960447c5cb...  ...     63130
# 266      -                       quay.io/nf-core/ubuntu:20.04  ...         3
# 267      -   quay.io/biocontainers/multiqc:1.13--pyhdfd78af_0  ...     10715
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/0e/3803359c26a30cca1e0b195da315e6       -             -
# 1    /workspace/work/38/1b996c7b899bb63229f463b8fa6491       -             -
# 2    /workspace/work/24/1fd911a3662f5f87f8dba19bd36843       -             -
# 3    /workspace/work/5d/7df9583944c11978d04de45c496f6b       -             -
# 4    /workspace/work/4b/bc03314ca4bd7ae2f1351d9c5441ae       -             -
# ..                                                 ...     ...           ...
# 263  /workspace/work/5e/e7bdbf0aedf8620501bfa79b42425b       -             -
# 264  /workspace/work/31/9f0b57de5186490892a37e3d2438ba       -             -
# 265  /workspace/work/63/a4be674cbbff721cb096688ac8af72       -             -
# 266  /workspace/work/ba/8c84e9296780c9f44312b4d6057633       -             -
# 267  /workspace/work/00/86bc4adfbb4cd25ba756015ed96785       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       138.8132
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      3422.6386
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     15380.3734
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     19066.8807
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      2005.1204
# ..                                         ...            ...
# 263  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       153.8419
# 264  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       436.4880
# 265  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     52399.0773
# 266  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz            NaN
# 267  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      7675.6447
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          atacseq           1      gu-cluster
# 1                        1          atacseq           1      gu-cluster
# 2                        0          atacseq           1      gu-cluster
# 3                        1          atacseq           1      gu-cluster
# 4                        1          atacseq           1      gu-cluster
# ..                     ...              ...         ...             ...
# 263                      0          atacseq           1      gu-cluster
# 264                      0          atacseq           1      gu-cluster
# 265                      1          atacseq           1      gu-cluster
# 266                      0          atacseq           1      gu-cluster
# 267                      0          atacseq           1      gu-cluster
#
# [268 rows x 44 columns],      task_id    hostname                                  native_id  \
# 0          1  gpgnode-15  nf-ad785bdd4d8bf6c93e60a67b955c0b95-517be
# 1          3  gpgnode-15  nf-b9a4d45eb69db59ecf9f3c5943e742e7-966ad
# 2          5  gpgnode-16  nf-026d6571d4e17d1a8915f48949b82919-7cce9
# 3          2  gpgnode-13  nf-6b5f334670e4a802b65043b9f4b7d16f-693c5
# 4          7  gpgnode-15  nf-d2a0b0080f488600ec761313498e4872-79207
# ..       ...         ...                                        ...
# 263      265  gpgnode-15  nf-eff02a4a946b4b8fab9a7603be6b3eb6-2a5e5
# 264      266  gpgnode-16  nf-4226826194232785c55e62832286b401-06227
# 265      257  gpgnode-14  nf-b519999ed0117fb91bdf7b4127355692-98056
# 266      267  gpgnode-16  nf-f4f058cbabff3068dce6533d0132e0be-d941b
# 267      268  gpgnode-14  nf-8b6f68ffb9d2b5bf980d815ae602f775-2d508
#
#                                                process                   tag  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  samplesheet_full.csv
# 1        NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED             genes.gtf
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  GM12878_FAST_REP1_T1
# 3    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...             genome.fa
# 4    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  GM12878_FAST_REP2_T1
# ..                                                 ...                   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV                     -
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...                     -
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 267                     NFCORE_ATACSEQ:ATACSEQ:MULTIQC                     -
#
#                                                   name     status  exit  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  COMPLETED     0
# 3    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# 4    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  COMPLETED     0
# ..                                                 ...        ...   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV  COMPLETED     0
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...  COMPLETED     0
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 267                 NFCORE_ATACSEQ:ATACSEQ:MULTIQC (1)  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         2
# 1        -                  quay.io/biocontainers/perl:5.26.2  ...      8809
# 2        -             quay.io/biocontainers/fastqc:0.11.9--0  ...        11
# 3        -  quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      1899
# 4        -             quay.io/biocontainers/fastqc:0.11.9--0  ...         7
# ..     ...                                                ...  ...       ...
# 263      -                 quay.io/biocontainers/python:3.8.3  ...         2
# 264      -   quay.io/biocontainers/multiqc:1.14--pyhdfd78af_0  ...         0
# 265      -  quay.io/biocontainers/mulled-v2-8186960447c5cb...  ...     67708
# 266      -                       quay.io/nf-core/ubuntu:20.04  ...        12
# 267      -   quay.io/biocontainers/multiqc:1.13--pyhdfd78af_0  ...     10845
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/ad/785bdd4d8bf6c93e60a67b955c0b95       -             -
# 1    /workspace/work/b9/a4d45eb69db59ecf9f3c5943e742e7       -             -
# 2    /workspace/work/02/6d6571d4e17d1a8915f48949b82919       -             -
# 3    /workspace/work/6b/5f334670e4a802b65043b9f4b7d16f       -             -
# 4    /workspace/work/d2/a0b0080f488600ec761313498e4872       -             -
# ..                                                 ...     ...           ...
# 263  /workspace/work/ef/f02a4a946b4b8fab9a7603be6b3eb6       -             -
# 264  /workspace/work/42/26826194232785c55e62832286b401       -             -
# 265  /workspace/work/b5/19999ed0117fb91bdf7b4127355692       -             -
# 266  /workspace/work/f4/f058cbabff3068dce6533d0132e0be       -             -
# 267  /workspace/work/8b/6f68ffb9d2b5bf980d815ae602f775       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        74.3558
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     10262.9591
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     14337.0754
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      1666.6521
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     17748.3058
# ..                                         ...            ...
# 263  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       150.5978
# 264  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        61.1792
# 265  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     59050.7052
# 266  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       119.3514
# 267  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      9743.3075
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          atacseq           2      gu-cluster
# 1                        1          atacseq           2      gu-cluster
# 2                        0          atacseq           2      gu-cluster
# 3                        0          atacseq           2      gu-cluster
# 4                        1          atacseq           2      gu-cluster
# ..                     ...              ...         ...             ...
# 263                      0          atacseq           2      gu-cluster
# 264                      0          atacseq           2      gu-cluster
# 265                      0          atacseq           2      gu-cluster
# 266                      0          atacseq           2      gu-cluster
# 267                      0          atacseq           2      gu-cluster
#
# [268 rows x 44 columns],      task_id    hostname                                  native_id  \
# 0          1  gpgnode-15  nf-fcee29d34be6a9a161a30886cfbf52ba-795a0
# 1          3  gpgnode-15  nf-455c75b9954aa8eff2d33fd3866af6a0-567e9
# 2          7  gpgnode-13  nf-1665870cb55f7cb9920be3a727db4c9e-64f85
# 3         14  gpgnode-14  nf-42d2546587bc202b26352786873764af-d3c98
# 4          2  gpgnode-13  nf-4583f60a62c4927a2586dc2937522753-fefd6
# ..       ...         ...                                        ...
# 263      265  gpgnode-14  nf-9880d0cb02f128e9ccf8c7ed7fbfb29f-4eaab
# 264      266  gpgnode-14  nf-a4c2c0c5b533faaf7f2400e916c74fdc-c7392
# 265      257  gpgnode-15  nf-59e141f78b912fcbb953fb1339684bf0-f1f10
# 266      267  gpgnode-15  nf-7c1871fd8de04bcd941aec45c3c78d5f-4f8e2
# 267      268  gpgnode-16  nf-cb426030c67c829f106e8a9114b3c1dd-928a4
#
#                                                process                   tag  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  samplesheet_full.csv
# 1        NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED             genes.gtf
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  GM12878_FAST_REP2_T1
# 3    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:TSS_EXTRACT                     -
# 4    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...             genome.fa
# ..                                                 ...                   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV                     -
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...                     -
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...          GM12878_OMNI
# 267                     NFCORE_ATACSEQ:ATACSEQ:MULTIQC                     -
#
#                                                   name     status  exit  \
# 0    NFCORE_ATACSEQ:ATACSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 2    NFCORE_ATACSEQ:ATACSEQ:FASTQ_FASTQC_UMITOOLS_T...  COMPLETED     0
# 3    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:TSS_EXTRACT  COMPLETED     0
# 4    NFCORE_ATACSEQ:ATACSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# ..                                                 ...        ...   ...
# 263                         NFCORE_ATACSEQ:ATACSEQ:IGV  COMPLETED     0
# 264  NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...  COMPLETED     0
# 265  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 266  NFCORE_ATACSEQ:ATACSEQ:MERGED_REPLICATE_CALL_A...  COMPLETED     0
# 267                 NFCORE_ATACSEQ:ATACSEQ:MULTIQC (1)  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         0
# 1        -                  quay.io/biocontainers/perl:5.26.2  ...       682
# 2        -             quay.io/biocontainers/fastqc:0.11.9--0  ...         5
# 3        -                       quay.io/nf-core/ubuntu:20.04  ...         1
# 4        -  quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      1502
# ..     ...                                                ...  ...       ...
# 263      -                 quay.io/biocontainers/python:3.8.3  ...         2
# 264      -   quay.io/biocontainers/multiqc:1.14--pyhdfd78af_0  ...         0
# 265      -  quay.io/biocontainers/mulled-v2-8186960447c5cb...  ...     65653
# 266      -                       quay.io/nf-core/ubuntu:20.04  ...         3
# 267      -   quay.io/biocontainers/multiqc:1.13--pyhdfd78af_0  ...     10681
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/fc/ee29d34be6a9a161a30886cfbf52ba       -             -
# 1    /workspace/work/45/5c75b9954aa8eff2d33fd3866af6a0       -             -
# 2    /workspace/work/16/65870cb55f7cb9920be3a727db4c9e       -             -
# 3    /workspace/work/42/d2546587bc202b26352786873764af       -             -
# 4    /workspace/work/45/83f60a62c4927a2586dc2937522753       -             -
# ..                                                 ...     ...           ...
# 263  /workspace/work/98/80d0cb02f128e9ccf8c7ed7fbfb29f       -             -
# 264  /workspace/work/a4/c2c0c5b533faaf7f2400e916c74fdc       -             -
# 265  /workspace/work/59/e141f78b912fcbb953fb1339684bf0       -             -
# 266  /workspace/work/7c/1871fd8de04bcd941aec45c3c78d5f       -             -
# 267  /workspace/work/cb/426030c67c829f106e8a9114b3c1dd       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        73.5368
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      1296.0663
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      9776.0666
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      4353.7878
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      1648.9500
# ..                                         ...            ...
# 263  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       157.2652
# 264  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        66.0825
# 265  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     57478.2351
# 266  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz            NaN
# 267  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      8223.0225
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          atacseq           3      gu-cluster
# 1                        0          atacseq           3      gu-cluster
# 2                        0          atacseq           3      gu-cluster
# 3                        1          atacseq           3      gu-cluster
# 4                        0          atacseq           3      gu-cluster
# ..                     ...              ...         ...             ...
# 263                      0          atacseq           3      gu-cluster
# 264                      0          atacseq           3      gu-cluster
# 265                      0          atacseq           3      gu-cluster
# 266                      0          atacseq           3      gu-cluster
# 267                      0          atacseq           3      gu-cluster
#
# [268 rows x 44 columns],      task_id    hostname                                  native_id  \
# 0          2  gpgnode-13                                      91195
# 1          1  gpgnode-14  nf-b695279bfca7c89fb5e1930ade21b687-65ca8
# 2          3  gpgnode-18  nf-579ef6a7485e229e4add142514104d26-5ad7e
# 3          5  gpgnode-16  nf-e9b613123a51bae72b96a36343757761-74075
# 4          7  gpgnode-14  nf-2eb513a77f4509f6a441a9148c8763b1-663a3
# ..       ...         ...                                        ...
# 309      311  gpgnode-18  nf-d7b9c915c0ededfafd9e8927ca1619eb-7eb0b
# 310      297  gpgnode-14  nf-8630628a9d90eda4a697cf062032ea92-e5260
# 311      313  gpgnode-14  nf-a5cb3b3b3e39e0930c712c6d338e04cc-43362
# 312      314  gpgnode-14  nf-3b493f6bfbc76bc06ca64165a57ee4e7-7bd8b
# 313      312  gpgnode-18  nf-448eb386c748a4f70d5dd6e4180e7fa1-cb065
#
#                                                process  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...
# 2        NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED
# 3      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# 4      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# ..                                                 ...
# 309       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
# 310     NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_COMPUTEMATRIX
# 311       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE
# 312                     NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC
# 313       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
#
#                                tag  \
# 0                chipseq-input.csv
# 1                        genome.fa
# 2                        genes.gtf
# 3    H3K4me1_LAPC4_Control_REP1_T1
# 4    H3K4me1_LAPC4_Control_REP2_T1
# ..                             ...
# 309       H3K4me1_LAPC4_R1881_REP1
# 310       H3K4me1_LAPC4_R1881_REP2
# 311       H3K4me1_LAPC4_R1881_REP2
# 312                              -
# 313       H3K4me1_LAPC4_R1881_REP2
#
#                                                   name     status  exit  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# 2    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 3    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# 4    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# ..                                                 ...        ...   ...
# 309  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
# 310  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_COMPUTEMATRIX...  COMPLETED     0
# 311  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE (...  COMPLETED     0
# 312                 NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC (1)  COMPLETED     0
# 313  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         3
# 1        -  quay.io/biocontainers/samtools:1.15.1--h1170115_0  ...      2027
# 2        -                  quay.io/biocontainers/perl:5.26.2  ...      4027
# 3        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        13
# 4        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        14
# ..     ...                                                ...  ...       ...
# 309      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     40957
# 310      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...   1456012
# 311      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...      6149
# 312      -  quay.io/biocontainers/multiqc:1.13a--pyhdfd78af_1  ...     20998
# 313      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     39729
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/72/149bd7abc51a95175c212b24abdb21       -             -
# 1    /workspace/work/b6/95279bfca7c89fb5e1930ade21b687       -             -
# 2    /workspace/work/57/9ef6a7485e229e4add142514104d26       -             -
# 3    /workspace/work/e9/b613123a51bae72b96a36343757761       -             -
# 4    /workspace/work/2e/b513a77f4509f6a441a9148c8763b1       -             -
# ..                                                 ...     ...           ...
# 309  /workspace/work/d7/b9c915c0ededfafd9e8927ca1619eb       -             -
# 310  /workspace/work/86/30628a9d90eda4a697cf062032ea92       -             -
# 311  /workspace/work/a5/cb3b3b3e39e0930c712c6d338e04cc       -             -
# 312  /workspace/work/3b/493f6bfbc76bc06ca64165a57ee4e7       -             -
# 313  /workspace/work/44/8eb386c748a4f70d5dd6e4180e7fa1       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz            NaN
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5388.2046
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      6176.3546
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     12729.7163
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     13755.9656
# ..                                         ...            ...
# 309  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     28333.4631
# 310  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz    182127.2785
# 311  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5656.0016
# 312  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     15991.3956
# 313  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     26223.6036
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          chipseq           1      gu-cluster
# 1                        1          chipseq           1      gu-cluster
# 2                        1          chipseq           1      gu-cluster
# 3                        0          chipseq           1      gu-cluster
# 4                        1          chipseq           1      gu-cluster
# ..                     ...              ...         ...             ...
# 309                      0          chipseq           1      gu-cluster
# 310                      0          chipseq           1      gu-cluster
# 311                      0          chipseq           1      gu-cluster
# 312                      0          chipseq           1      gu-cluster
# 313                      0          chipseq           1      gu-cluster
#
# [314 rows x 44 columns],      task_id    hostname                                  native_id  \
# 0          3  gpgnode-13                                     109603
# 1          2  gpgnode-14  nf-3572ea3ba0d9177d6846e39e156df242-7662e
# 2          1  gpgnode-18  nf-7f3481f3f30af3328a3c6fa6c4ea7fa4-132ca
# 3          4  gpgnode-13  nf-73d53fcab5b2e0bb94fec5351d4ed714-b24da
# 4          6  gpgnode-16  nf-2a89bb04099403ef5639c5c8d10242d2-93653
# ..       ...         ...                                        ...
# 309      311  gpgnode-14  nf-943737de1f62b5d4fb2377af2efede6d-14ff7
# 310      301  gpgnode-16  nf-6be3f50f62b00e66fb5b5832c9587f3b-2ec79
# 311      312  gpgnode-18  nf-a51ad29affa63d241e96183bb93e759b-8c13e
# 312      314  gpgnode-16  nf-979ed97e98dc0e789b812f3075517c36-0129a
# 313      313  gpgnode-14  nf-95f2a29a50dba039c0b3369a265f9d64-34590
#
#                                                process  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...
# 2        NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED
# 3      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# 4      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# ..                                                 ...
# 309       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
# 310     NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_COMPUTEMATRIX
# 311       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE
# 312                     NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC
# 313       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
#
#                                tag  \
# 0                chipseq-input.csv
# 1                        genome.fa
# 2                        genes.gtf
# 3    H3K4me1_LAPC4_Control_REP1_T1
# 4    H3K4me1_LAPC4_Control_REP2_T1
# ..                             ...
# 309       H3K4me1_LAPC4_R1881_REP1
# 310       H3K4me1_LAPC4_R1881_REP2
# 311       H3K4me1_LAPC4_R1881_REP2
# 312                              -
# 313       H3K4me1_LAPC4_R1881_REP2
#
#                                                   name     status  exit  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# 2    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 3    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# 4    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# ..                                                 ...        ...   ...
# 309  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
# 310  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_COMPUTEMATRIX...  COMPLETED     0
# 311  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE (...  COMPLETED     0
# 312                 NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC (1)  COMPLETED     0
# 313  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         4
# 1        -  quay.io/biocontainers/samtools:1.15.1--h1170115_0  ...      1471
# 2        -                  quay.io/biocontainers/perl:5.26.2  ...      6670
# 3        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        17
# 4        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        15
# ..     ...                                                ...  ...       ...
# 309      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     42547
# 310      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...   1429567
# 311      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...      6045
# 312      -  quay.io/biocontainers/multiqc:1.13a--pyhdfd78af_1  ...     20364
# 313      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     41101
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/61/2cea7079078de46fbeffe024df7a1a       -             -
# 1    /workspace/work/35/72ea3ba0d9177d6846e39e156df242       -             -
# 2    /workspace/work/7f/3481f3f30af3328a3c6fa6c4ea7fa4       -             -
# 3    /workspace/work/73/d53fcab5b2e0bb94fec5351d4ed714       -             -
# 4    /workspace/work/2a/89bb04099403ef5639c5c8d10242d2       -             -
# ..                                                 ...     ...           ...
# 309  /workspace/work/94/3737de1f62b5d4fb2377af2efede6d       -             -
# 310  /workspace/work/6b/e3f50f62b00e66fb5b5832c9587f3b       -             -
# 311  /workspace/work/a5/1ad29affa63d241e96183bb93e759b       -             -
# 312  /workspace/work/97/9ed97e98dc0e789b812f3075517c36       -             -
# 313  /workspace/work/95/f2a29a50dba039c0b3369a265f9d64       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz            NaN
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      4747.6332
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5877.7897
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     10545.2000
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      9651.6447
# ..                                         ...            ...
# 309  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     30053.4666
# 310  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz    161998.2585
# 311  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      4818.6686
# 312  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     14134.1112
# 313  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     31177.7421
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          chipseq           2      gu-cluster
# 1                        0          chipseq           2      gu-cluster
# 2                        0          chipseq           2      gu-cluster
# 3                        0          chipseq           2      gu-cluster
# 4                        0          chipseq           2      gu-cluster
# ..                     ...              ...         ...             ...
# 309                      0          chipseq           2      gu-cluster
# 310                      0          chipseq           2      gu-cluster
# 311                      0          chipseq           2      gu-cluster
# 312                      0          chipseq           2      gu-cluster
# 313                      0          chipseq           2      gu-cluster
#
# [314 rows x 44 columns],      task_id    hostname                                  native_id  \
# 0          1  gpgnode-13                                     128794
# 1          2  gpgnode-14  nf-00011a881bf06a9f897818d98cdaa6dc-6b4d1
# 2          3  gpgnode-18  nf-461156f68c1235cc9d5c02cc87aa57d9-46baa
# 3          4  gpgnode-16  nf-aba14a2e5e3cc92a0cad65fef138d600-8ff7f
# 4          7  gpgnode-14  nf-de6b7f40f39e69e7ac55cf64b634aa2d-903c2
# ..       ...         ...                                        ...
# 309      310  gpgnode-18  nf-e1428bf5dc864e2a6dfdf50a527b68d4-4955a
# 310      309  gpgnode-13  nf-36d82fb0afc5051c60577c023bbc888b-9577a
# 311      314  gpgnode-18  nf-898012898670b7261ee5f3bdc51ee1c3-91384
# 312      311  gpgnode-14  nf-33f63327908981a9981b25ad00e79e1d-29ea4
# 313      312  gpgnode-16  nf-9605b3bfd72963666e52ae8b9b24bfc0-0078e
#
#                                                process  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...
# 2        NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED
# 3      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# 4      NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQC
# ..                                                 ...
# 309       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE
# 310       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
# 311                     NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC
# 312       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
# 313       NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP
#
#                                tag  \
# 0                chipseq-input.csv
# 1                        genome.fa
# 2                        genes.gtf
# 3    H3K4me1_LAPC4_Control_REP1_T1
# 4    H3K4me1_LAPC4_Control_REP2_T1
# ..                             ...
# 309       H3K4me1_LAPC4_R1881_REP2
# 310        H3K4me1_LAPC4_Daro_REP1
# 311                              -
# 312       H3K4me1_LAPC4_R1881_REP2
# 313       H3K4me1_LAPC4_R1881_REP1
#
#                                                   name     status  exit  \
# 0    NFCORE_CHIPSEQ:CHIPSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0
# 1    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:CUSTOM_G...  COMPLETED     0
# 2    NFCORE_CHIPSEQ:CHIPSEQ:PREPARE_GENOME:GTF2BED ...  COMPLETED     0
# 3    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# 4    NFCORE_CHIPSEQ:CHIPSEQ:FASTQC_TRIMGALORE:FASTQ...  COMPLETED     0
# ..                                                 ...        ...   ...
# 309  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTPROFILE (...  COMPLETED     0
# 310  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
# 311                 NFCORE_CHIPSEQ:CHIPSEQ:MULTIQC (1)  COMPLETED     0
# 312  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
# 313  NFCORE_CHIPSEQ:CHIPSEQ:DEEPTOOLS_PLOTHEATMAP (...  COMPLETED     0
#
#     module                                          container  ...  inv_ctxt  \
# 0        -                 quay.io/biocontainers/python:3.8.3  ...         1
# 1        -  quay.io/biocontainers/samtools:1.15.1--h1170115_0  ...      3312
# 2        -                  quay.io/biocontainers/perl:5.26.2  ...      4048
# 3        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        13
# 4        -  quay.io/biocontainers/trim-galore:0.6.10--hdfd...  ...        17
# ..     ...                                                ...  ...       ...
# 309      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...      6038
# 310      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     45737
# 311      -  quay.io/biocontainers/multiqc:1.13a--pyhdfd78af_1  ...     20689
# 312      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     37384
# 313      -  quay.io/biocontainers/deeptools:3.5.5--pyhdfd7...  ...     40287
#
#                                                workdir scratch  error_action  \
# 0    /workspace/work/ea/77eeb8127e7a6915b61838d335b042       -             -
# 1    /workspace/work/00/011a881bf06a9f897818d98cdaa6dc       -             -
# 2    /workspace/work/46/1156f68c1235cc9d5c02cc87aa57d9       -             -
# 3    /workspace/work/ab/a14a2e5e3cc92a0cad65fef138d600       -             -
# 4    /workspace/work/de/6b7f40f39e69e7ac55cf64b634aa2d       -             -
# ..                                                 ...     ...           ...
# 309  /workspace/work/e1/428bf5dc864e2a6dfdf50a527b68d4       -             -
# 310  /workspace/work/36/d82fb0afc5051c60577c023bbc888b       -             -
# 311  /workspace/work/89/8012898670b7261ee5f3bdc51ee1c3       -             -
# 312  /workspace/work/33/f63327908981a9981b25ad00e79e1d       -             -
# 313  /workspace/work/96/05b3bfd72963666e52ae8b9b24bfc0       -             -
#
#                                      cpu_model  task_energy_j  \
# 0    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        74.9240
# 1    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      4318.3211
# 2    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5119.5549
# 3    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     11750.3818
# 4    Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     14202.5168
# ..                                         ...            ...
# 309  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      4783.2530
# 310  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     28471.8776
# 311  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     14572.2211
# 312  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     27631.0698
# 313  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz     26604.6712
#
#      concurrent_task_count  source_workflow  source_run  source_cluster
# 0                        0          chipseq           3      gu-cluster
# 1                        1          chipseq           3      gu-cluster
# 2                        0          chipseq           3      gu-cluster
# 3                        0          chipseq           3      gu-cluster
# 4                        1          chipseq           3      gu-cluster
# ..                     ...              ...         ...             ...
# 309                      0          chipseq           3      gu-cluster
# 310                      1          chipseq           3      gu-cluster
# 311                      0          chipseq           3      gu-cluster
# 312                      0          chipseq           3      gu-cluster
# 313                      0          chipseq           3      gu-cluster
#
# [314 rows x 44 columns],     task_id    hostname                                  native_id  \
# 0         1  gpgnode-14  nf-94afe80e3586e5cfb75dfe4f6fae5a1d-f830f
# 1         2  gpgnode-13  nf-fda5e4253c5f6f9acfb882528dfc70ff-341b5
# 2         8  gpgnode-18  nf-61cd53edafbb93b66b4239d7811acc31-3ca47
# 3         5  gpgnode-13  nf-65f3979f68b6b3029e6e94bb29be39cf-4f33d
# 4         4  gpgnode-13  nf-dad8fe6404137760ec5a0d761648b438-4429f
# ..      ...         ...                                        ...
# 87       86  gpgnode-13  nf-3b7438c59b6bd3189649685562e9790a-ccb7e
# 88       90  gpgnode-16  nf-04ffba645fdf4795b502bda34c104b20-e6d76
# 89       89  gpgnode-14  nf-6523fc5268de542e8a48443a9cd1b3ea-15e48
# 90       91  gpgnode-18  nf-131d71ffe289d212614e8d3ff793e137-8c566
# 91       92  gpgnode-18  nf-fc4504b29f2d9f2577875b1c453c962d-0a79e
#
#                                               process                   tag  \
# 0   NFCORE_NANOSEQ:NANOSEQ:INPUT_CHECK:SAMPLESHEET...  samplesheet_full.csv
# 1   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...               A549_R1
# 2   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...             genome.fa
# 3   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...             genome.fa
# 4   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:GET_CHRO...             genome.fa
# ..                                                ...                   ...
# 87                       NFCORE_NANOSEQ:NANOSEQ:BAMBU                     -
# 88  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...                     -
# 89  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...                     -
# 90  NFCORE_NANOSEQ:NANOSEQ:CUSTOM_DUMPSOFTWAREVERS...                     -
# 91                     NFCORE_NANOSEQ:NANOSEQ:MULTIQC                     -
#
#                                                  name     status  exit module  \
# 0   NFCORE_NANOSEQ:NANOSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0      -
# 1   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...  COMPLETED     0      -
# 2   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...  COMPLETED     0      -
# 3   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...  COMPLETED     0      -
# 4   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:GET_CHRO...  COMPLETED     0      -
# ..                                                ...        ...   ...    ...
# 87                   NFCORE_NANOSEQ:NANOSEQ:BAMBU (1)  COMPLETED     0      -
# 88  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...  COMPLETED     0      -
# 89  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...  COMPLETED     0      -
# 90  NFCORE_NANOSEQ:NANOSEQ:CUSTOM_DUMPSOFTWAREVERS...  COMPLETED     0      -
# 91                 NFCORE_NANOSEQ:NANOSEQ:MULTIQC (1)  COMPLETED     0      -
#
#                                             container  ...  inv_ctxt  \
# 0                  quay.io/biocontainers/python:3.8.3  ...        16
# 1              quay.io/biocontainers/fastqc:0.11.9--0  ...        23
# 2   quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      2125
# 3   quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      1647
# 4     quay.io/biocontainers/samtools:1.13--h8c37831_0  ...      1511
# ..                                                ...  ...       ...
# 87  quay.io/biocontainers/bioconductor-bambu:3.0.8...  ...    469993
# 88  quay.io/biocontainers/mulled-v2-8849acf39a43cd...  ...      6741
# 89                  docker.io/yuukiiwa/nanoseq:dexseq  ...      5048
# 90   quay.io/biocontainers/multiqc:1.13--pyhdfd78af_0  ...         1
# 91   quay.io/biocontainers/multiqc:1.11--pyhdfd78af_0  ...      2829
#
#                                               workdir scratch  error_action  \
# 0   /workspace/work/94/afe80e3586e5cfb75dfe4f6fae5a1d       -             -
# 1   /workspace/work/fd/a5e4253c5f6f9acfb882528dfc70ff       -             -
# 2   /workspace/work/61/cd53edafbb93b66b4239d7811acc31       -             -
# 3   /workspace/work/65/f3979f68b6b3029e6e94bb29be39cf       -             -
# 4   /workspace/work/da/d8fe6404137760ec5a0d761648b438       -             -
# ..                                                ...     ...           ...
# 87  /workspace/work/3b/7438c59b6bd3189649685562e9790a       -             -
# 88  /workspace/work/04/ffba645fdf4795b502bda34c104b20       -             -
# 89  /workspace/work/65/23fc5268de542e8a48443a9cd1b3ea       -             -
# 90  /workspace/work/13/1d71ffe289d212614e8d3ff793e137       -             -
# 91  /workspace/work/fc/4504b29f2d9f2577875b1c453c962d       -             -
#
#                                     cpu_model  task_energy_j  \
# 0   Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz       260.0920
# 1   Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      3782.2856
# 2   Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5467.2481
# 3   Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      1325.3450
# 4   Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      1251.7893
# ..                                        ...            ...
# 87  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz    326007.6728
# 88  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      5351.7425
# 89  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      6113.0739
# 90  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz        62.9599
# 91  Intel(R) Xeon(R) CPU E5-2640 v2 @ 2.00GHz      2839.1949
#
#     concurrent_task_count  source_workflow  source_run  source_cluster
# 0                       0          nanoseq           1      gu-cluster
# 1                       0          nanoseq           1      gu-cluster
# 2                       1          nanoseq           1      gu-cluster
# 3                       0          nanoseq           1      gu-cluster
# 4                       0          nanoseq           1      gu-cluster
# ..                    ...              ...         ...             ...
# 87                      0          nanoseq           1      gu-cluster
# 88                      0          nanoseq           1      gu-cluster
# 89                      0          nanoseq           1      gu-cluster
# 90                      0          nanoseq           1      gu-cluster
# 91                      0          nanoseq           1      gu-cluster
#
# [92 rows x 44 columns],     task_id    hostname                                  native_id  \
# 0         1  gpgnode-14  nf-e284ece0d4570350510e71fdeb5cae73-838e3
# 1         3  gpgnode-14  nf-839ace44fc1f7c3996383aae4cecbb43-bd466
# 2         6  gpgnode-18  nf-ad2576b9e937b98ff809bc7994830cc0-78977
# 3         8  gpgnode-13  nf-123563e05afc5c8952f4cce2eb0d7f2b-cc548
# 4         5  gpgnode-18  nf-0660d717889212c0ba7e2b9217420bb7-9d8aa
# ..      ...         ...                                        ...
# 87       86  gpgnode-16  nf-fb74a5dfa78d58dfe2bc2975f1af184b-9685c
# 88       89  gpgnode-13  nf-6380044715b79fc65aa4148d6db43caf-9ee3f
# 89       90  gpgnode-14  nf-0e67b0e1a14befed1f45c7cb3f478308-6e371
# 90       91  gpgnode-14  nf-fe6c8fe33b8dad8ee007daa24dc782a0-2b41e
# 91       92  gpgnode-14  nf-10e0d0606d7bda2c862ade466d1dc4e4-0dddc
#
#                                               process                   tag  \
# 0   NFCORE_NANOSEQ:NANOSEQ:INPUT_CHECK:SAMPLESHEET...  samplesheet_full.csv
# 1   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...               A549_R1
# 2   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...               A549_R2
# 3   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...             genome.fa
# 4   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:GET_CHRO...             genome.fa
# ..                                                ...                   ...
# 87                       NFCORE_NANOSEQ:NANOSEQ:BAMBU                     -
# 88  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...                     -
# 89  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...                     -
# 90  NFCORE_NANOSEQ:NANOSEQ:CUSTOM_DUMPSOFTWAREVERS...                     -
# 91                     NFCORE_NANOSEQ:NANOSEQ:MULTIQC                     -
#
#                                                  name     status  exit module  \
# 0   NFCORE_NANOSEQ:NANOSEQ:INPUT_CHECK:SAMPLESHEET...  COMPLETED     0      -
# 1   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...  COMPLETED     0      -
# 2   NFCORE_NANOSEQ:NANOSEQ:QCFASTQ_NANOPLOT_FASTQC...  COMPLETED     0      -
# 3   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:SAMTOOLS...  COMPLETED     0      -
# 4   NFCORE_NANOSEQ:NANOSEQ:PREPARE_GENOME:GET_CHRO...  COMPLETED     0      -
# ..                                                ...        ...   ...    ...
# 87                   NFCORE_NANOSEQ:NANOSEQ:BAMBU (1)  COMPLETED     0      -
# 88  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...  COMPLETED     0      -
# 89  NFCORE_NANOSEQ:NANOSEQ:DIFFERENTIAL_DESEQ2_DEX...  COMPLETED     0      -
# 90  NFCORE_NANOSEQ:NANOSEQ:CUSTOM_DUMPSOFTWAREVERS...  COMPLETED     0      -
# 91                 NFCORE_NANOSEQ:NANOSEQ:MULTIQC (1)  COMPLETED     0      -
#
#                                             container  ...  inv_ctxt  \
# 0                  quay.io/biocontainers/python:3.8.3  ...         2
# 1              quay.io/biocontainers/fastqc:0.11.9--0  ...         6
# 2              quay.io/biocontainers/fastqc:0.11.9--0  ...        14
# 3   quay.io/biocontainers/samtools:1.16.1--h6899075_1  ...      1435
# ...
# 1266               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1267               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1268                       NFCORE_RNASEQ:RNASEQ:MULTIQC
#
#                                  tag  \
# 0                          input.csv
# 1                          genome.fa
# 2                          genome.fa
# 3      TREATMENT_mIFNa11_100000_REP3
# 4       TREATMENT_rhIFNb_100000_REP2
# ...                              ...
# 1264   TREATMENT_rhINFa2b_10000_REP2
# 1265     TREATMENT_rhIFNb_10000_REP2
# 1266  TREATMENT_rhINFa2b_100000_REP1
# 1267   TREATMENT_rhINFa2b_10000_REP2
# 1268                               -
#
#                                                    name     status  exit  \
# 0     NFCORE_RNASEQ:RNASEQ:INPUT_CHECK:SAMPLESHEET_C...  COMPLETED     0
# 1     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:CUSTOM_GET...  COMPLETED     0
# 2     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:GTF_GENE_F...  COMPLETED     0
# 3     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# 4     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# ...                                                 ...        ...   ...
# 1264  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...  COMPLETED     0
# 1265  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1266  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1267  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1268                   NFCORE_RNASEQ:RNASEQ:MULTIQC (1)  COMPLETED     0
#
#      module  ... vol_ctxt  inv_ctxt  \
# 0         -  ...        2         0
# 1         -  ...      176       986
# 2         -  ...       49      1011
# 3         -  ...       37         0
# 4         -  ...       12         1
# ...     ...  ...      ...       ...
# 1264      -  ...      393       545
# 1265      -  ...       17         8
# 1266      -  ...       12         2
# 1267      -  ...       33         8
# 1268      -  ...     6678      5449
#
#                                                 workdir scratch  error_action  \
# 0     /input/data/work/af/0e627565592a8742baf11d341f...    True             -
# 1     /input/data/work/41/5a579fec0800a3ba1a56c56dfe...    True             -
# 2     /input/data/work/22/47d97385f2ffda701e0e7a4271...    True             -
# 3     /input/data/work/00/3588bdd743c004a0c8103c4244...    True             -
# 4     /input/data/work/79/b823ebba74970632c4656c6981...    True             -
# ...                                                 ...     ...           ...
# 1264  /input/data/work/50/41423886317b51ce3654e9d607...    True             -
# 1265  /input/data/work/2f/6f728176ff4e525562ed9a125b...    True             -
# 1266  /input/data/work/e1/792ce3a6fdad1d9e35e661b87c...    True             -
# 1267  /input/data/work/b7/e0d93b785de2651514d674fc9c...    True             -
# 1268  /input/data/work/20/d8801b89868aa38cb7243c78bc...    True             -
#
#       task_energy_j  concurrent_task_count  source_workflow  source_run  \
# 0          364.1591                      0           rnaseq           1
# 1         1053.4603                      0           rnaseq           1
# 2         1161.1756                      0           rnaseq           1
# 3        14556.2940                      4           rnaseq           1
# 4        15567.9423                      5           rnaseq           1
# ...             ...                    ...              ...         ...
# 1264      1946.9959                      1           rnaseq           1
# 1265    140981.9710                     66           rnaseq           1
# 1266    151966.4074                     70           rnaseq           1
# 1267    150447.3024                     42           rnaseq           1
# 1268      8356.4694                      0           rnaseq           1
#
#       source_cluster
# 0         hu-cluster
# 1         hu-cluster
# 2         hu-cluster
# 3         hu-cluster
# 4         hu-cluster
# ...              ...
# 1264      hu-cluster
# 1265      hu-cluster
# 1266      hu-cluster
# 1267      hu-cluster
# 1268      hu-cluster
#
# [1269 rows x 44 columns],       task_id       hostname       hash  \
# 0           3  hu-worker-c45  ec/a4a984
# 1           2  hu-worker-c42  8e/765b69
# 2           1  hu-worker-c44  a4/ad456d
# 3          45  hu-worker-c44  86/abdf30
# 4          13  hu-worker-c45  dc/f0803a
# ...       ...            ...        ...
# 1264     1268  hu-worker-c45  61/604565
# 1265      902  hu-worker-c44  5a/cdfc72
# 1266     1119  hu-worker-c40  a7/a465d6
# 1267     1134  hu-worker-c42  9d/1338ab
# 1268     1269  hu-worker-c44  51/ab7c4b
#
#                                       native_id  \
# 0     nf-eca4a984ca4402180cff22bee2f413a5-a12c2
# 1     nf-8e765b69ea102b678135dc5b6125023b-b68e9
# 2     nf-a4ad456d592423972319717822a908da-63e34
# 3     nf-86abdf309c2c8c76e5660b44737362c2-9b566
# 4     nf-dcf0803a24a65420852095858b177e78-9b62c
# ...                                         ...
# 1264  nf-61604565d8b532777270dd8ab85a92ef-00e6f
# 1265  nf-5acdfc72ee13fcb724c703ae1140194b-e021a
# 1266  nf-a7a465d6631c2b7c6da5ab2853de89d2-28688
# 1267  nf-9d1338aba296a603fd7a5fafe50051e7-49c21
# 1268  nf-51ab7c4b7fe0572035e8624ca83fe4e3-9f864
#
#                                                 process  \
# 0     NFCORE_RNASEQ:RNASEQ:INPUT_CHECK:SAMPLESHEET_C...
# 1     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:CUSTOM_GET...
# 2     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:GTF_GENE_F...
# 3     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...
# 4     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...
# ...                                                 ...
# 1264  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...
# 1265               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1266               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1267               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1268                       NFCORE_RNASEQ:RNASEQ:MULTIQC
#
#                                 tag  \
# 0                         input.csv
# 1                         genome.fa
# 2                         genome.fa
# 3      TREATMENT_rhIFNb_100000_REP3
# 4     TREATMENT_mIFNa11_100000_REP3
# ...                             ...
# 1264    TREATMENT_mIFNa11_1000_REP2
# 1265  TREATMENT_rhINFa2b_10000_REP2
# 1266     TREATMENT_rhIFNb_1000_REP3
# 1267    TREATMENT_mIFNa11_1000_REP2
# 1268                              -
#
#                                                    name     status  exit  \
# 0     NFCORE_RNASEQ:RNASEQ:INPUT_CHECK:SAMPLESHEET_C...  COMPLETED     0
# 1     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:CUSTOM_GET...  COMPLETED     0
# 2     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:GTF_GENE_F...  COMPLETED     0
# 3     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# 4     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# ...                                                 ...        ...   ...
# 1264  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...  COMPLETED     0
# 1265  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1266  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1267  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1268                   NFCORE_RNASEQ:RNASEQ:MULTIQC (1)  COMPLETED     0
#
#      module  ... vol_ctxt  inv_ctxt  \
# 0         -  ...        4         0
# 1         -  ...       45       883
# 2         -  ...       43      1105
# 3         -  ...      129         0
# 4         -  ...       26         1
# ...     ...  ...      ...       ...
# 1264      -  ...     4491      4488
# 1265      -  ...       12        12
# 1266      -  ...       26         3
# 1267      -  ...       17         1
# 1268      -  ...     5742      5465
#
#                                                 workdir scratch  error_action  \
# 0     /input/data/work/ec/a4a984ca4402180cff22bee2f4...    True             -
# 1     /input/data/work/8e/765b69ea102b678135dc5b6125...    True             -
# 2     /input/data/work/a4/ad456d592423972319717822a9...    True             -
# 3     /input/data/work/86/abdf309c2c8c76e5660b447373...    True             -
# 4     /input/data/work/dc/f0803a24a65420852095858b17...    True             -
# ...                                                 ...     ...           ...
# 1264  /input/data/work/61/604565d8b532777270dd8ab85a...    True             -
# 1265  /input/data/work/5a/cdfc72ee13fcb724c703ae1140...    True             -
# 1266  /input/data/work/a7/a465d6631c2b7c6da5ab2853de...    True             -
# 1267  /input/data/work/9d/1338aba296a603fd7a5fafe500...    True             -
# 1268  /input/data/work/51/ab7c4b7fe0572035e8624ca83f...    True             -
#
#       task_energy_j  concurrent_task_count  source_workflow  source_run  \
# 0               NaN                      0           rnaseq           2
# 1          914.6737                      3           rnaseq           2
# 2         1525.9440                      4           rnaseq           2
# 3        10530.2940                      4           rnaseq           2
# 4        16072.1215                      3           rnaseq           2
# ...             ...                    ...              ...         ...
# 1264      2313.8173                      2           rnaseq           2
# 1265    168753.2652                     91           rnaseq           2
# 1266    113302.6037                     32           rnaseq           2
# 1267    108001.2420                     21           rnaseq           2
# 1268      8353.6117                      0           rnaseq           2
#
#       source_cluster
# 0         hu-cluster
# 1         hu-cluster
# 2         hu-cluster
# 3         hu-cluster
# 4         hu-cluster
# ...              ...
# 1264      hu-cluster
# 1265      hu-cluster
# 1266      hu-cluster
# 1267      hu-cluster
# 1268      hu-cluster
#
# [1269 rows x 44 columns],       task_id       hostname       hash  \
# 0           3  hu-worker-c45  f1/0cdc4e
# 1           2  hu-worker-c44  6d/9dbec8
# 2           1  hu-worker-c40  17/864395
# 3          60  hu-worker-c44  53/1dd466
# 4          12  hu-worker-c44  32/91a075
# ...       ...            ...        ...
# 1264     1267  hu-worker-c44  04/93abc5
# 1265     1268  hu-worker-c42  90/d7b6e5
# 1266     1116  hu-worker-c45  3e/cf3886
# 1267     1134  hu-worker-c40  d0/6f7b30
# 1268     1269  hu-worker-c44  02/2be7d6
#
#                                       native_id  \
# 0     nf-f10cdc4e1bfa9bcd8b7f719655042a49-a578a
# 1     nf-6d9dbec892cf3631454b672c3e8dae70-96810
# 2     nf-178643952f6f95b1e0c12fb3a0c842f4-dcbe7
# 3     nf-531dd466e7ac2c76db69a5f8bc8672dd-8d599
# 4     nf-3291a075da8dbd07f3c7b7fd3066023a-e387d
# ...                                         ...
# 1264  nf-0493abc5ed17ab34dea995a0510522c2-2495b
# 1265  nf-90d7b6e589e7f1db496492743794c8f0-0b862
# 1266  nf-3ecf3886153b836acd118021f5c48947-d5aab
# 1267  nf-d06f7b30e8c68600232e5b57d42de4d5-4bd86
# 1268  nf-022be7d6ff9e61bc439cfc89fcd36056-020b3
#
#                                                 process  \
# 0     NFCORE_RNASEQ:RNASEQ:INPUT_CHECK:SAMPLESHEET_C...
# 1     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:GTF_GENE_F...
# 2     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:CUSTOM_GET...
# 3     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...
# 4     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...
# ...                                                 ...
# 1264  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...
# 1265  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...
# 1266               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1267               NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ
# 1268                       NFCORE_RNASEQ:RNASEQ:MULTIQC
#
#                                 tag  \
# 0                         input.csv
# 1                         genome.fa
# 2                         genome.fa
# 3      TREATMENT_rhIFNb_100000_REP3
# 4     TREATMENT_mIFNa11_100000_REP2
# ...                             ...
# 1264    TREATMENT_mIFNa11_1000_REP1
# 1265    TREATMENT_mIFNa11_1000_REP1
# 1266    TREATMENT_rhIFNa2b_100_REP1
# 1267    TREATMENT_mIFNa11_1000_REP1
# 1268                              -
#
#                                                    name     status  exit  \
# 0     NFCORE_RNASEQ:RNASEQ:INPUT_CHECK:SAMPLESHEET_C...  COMPLETED     0
# 1     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:GTF_GENE_F...  COMPLETED     0
# 2     NFCORE_RNASEQ:RNASEQ:PREPARE_GENOME:CUSTOM_GET...  COMPLETED     0
# 3     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# 4     NFCORE_RNASEQ:RNASEQ:FASTQ_FASTQC_UMITOOLS_TRI...  COMPLETED     0
# ...                                                 ...        ...   ...
# 1264  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...  COMPLETED     0
# 1265  NFCORE_RNASEQ:RNASEQ:BEDGRAPH_BEDCLIP_BEDGRAPH...  COMPLETED     0
# 1266  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1267  NFCORE_RNASEQ:RNASEQ:QUALIMAP_RNASEQ (TREATMEN...  COMPLETED     0
# 1268                   NFCORE_RNASEQ:RNASEQ:MULTIQC (1)  COMPLETED     0
#
#      module  ... vol_ctxt  inv_ctxt  \
# 0         -  ...        4         0
# 1         -  ...       42      1190
# 2         -  ...       39       704
# 3         -  ...       12        11
# 4         -  ...       34         8
# ...     ...  ...      ...       ...
# 1264      -  ...       32       187
# 1265      -  ...       13       172
# 1266      -  ...       31         1
# 1267      -  ...       30         9
# 1268      -  ...     6560      5559
#
#                                                 workdir scratch  error_action  \
# 0     /input/data/work/f1/0cdc4e1bfa9bcd8b7f71965504...    True             -
# 1     /input/data/work/6d/9dbec892cf3631454b672c3e8d...    True             -
# 2     /input/data/work/17/8643952f6f95b1e0c12fb3a0c8...    True             -
# 3     /input/data/work/53/1dd466e7ac2c76db69a5f8bc86...    True             -
# 4     /input/data/work/32/91a075da8dbd07f3c7b7fd3066...    True             -
# ...                                                 ...     ...           ...
# 1264  /input/data/work/04/93abc5ed17ab34dea995a05105...    True             -
# 1265  /input/data/work/90/d7b6e589e7f1db496492743794...    True             -
# 1266  /input/data/work/3e/cf3886153b836acd118021f5c4...    True             -
# 1267  /input/data/work/d0/6f7b30e8c68600232e5b57d42d...    True             -
# 1268  /input/data/work/02/2be7d6ff9e61bc439cfc89fcd3...    True             -
#
#       task_energy_j  concurrent_task_count  source_workflow  source_run  \
# 0               NaN                      0           rnaseq           3
# 1         1732.5842                      4           rnaseq           3
# 2         1572.1383                      4           rnaseq           3
# 3        10741.6315                      4           rnaseq           3
# 4        13243.1657                      5           rnaseq           3
# ...             ...                    ...              ...         ...
# 1264      1571.8067                      0           rnaseq           3
# 1265      1365.3647                      0           rnaseq           3
# 1266    101975.7129                     49           rnaseq           3
# 1267    114959.5751                     34           rnaseq           3
# 1268      8834.7216                      0           rnaseq           3
#
#       source_cluster
# 0         hu-cluster
# 1         hu-cluster
# 2         hu-cluster
# 3         hu-cluster
# 4         hu-cluster
# ...              ...
# 1264      hu-cluster
# 1265      hu-cluster
# 1266      hu-cluster
# 1267      hu-cluster
# 1268      hu-cluster
#
# [1269 rows x 44 columns]]

# %% [markdown]
# Saving the data into csv

# %%
directory_name = "../Processed_data"
augur_all.to_csv("../Processed_data/augur_combined_traces_data.csv",index=False)

# %% [markdown]
# ## 8. Replicate Aggregation
#
# Tasks move between nodes across replicate runs, so aggregation is keyed by `[source_cluster, source_workflow, process, tag, hostname]` — never blending energy across different nodes.

# %%
augur_agg = (
    augur_all.groupby(["source_cluster","source_workflow", "process", "tag", "hostname"])
    .agg(
        runtime_s=("realtime", "median"),
        peak_mem=("peak_rss", "median"),
        energy_j=("task_energy_j", "median"),
        runtime_std=("realtime", "std"),
        energy_std=("task_energy_j", "std"),
        rchar=("rchar", "median"),
        cpus=("cpus", "median"),
        concurrent_task_count=("concurrent_task_count", "median"),
        n_replicates=("realtime", "count"),
    )
    .reset_index()
)
print(augur_agg.shape)
print(augur_agg["n_replicates"].value_counts().sort_index())
print(augur_agg["hostname"].value_counts())
# Out:
# (13848, 14)
# n_replicates
# 1    10005
# 2     3352
# 3      480
# 4        5
# 5        2
# 7        2
# 8        1
# 9        1
# Name: count, dtype: int64
# hostname
# hu-worker-c44    3091
# hu-worker-c45    3039
# hu-worker-c40    2927
# hu-worker-c42    2798
# gpgnode-14        562
# gpgnode-16        478
# gpgnode-13        406
# gpgnode-18        390
# gpgnode-15        157
# Name: count, dtype: int64

# %% [markdown]
# ## 9. Hardware Specs Tables
#
# Per-machine specs for Lotaru, gu-cluster, and hu-cluster. Benchmark units are not comparable across sources (verified: Lotaru I/O is IOPS, Augur I/O is MB/s), so benchmark features are normalized per-source at modeling time — raw values kept here for transparency.

# %%
lotaru_spec_data = {
    "node" : ["local","a1","a2","n1","n2","c2"],
    "cores": [8,8,8,8,8,8],
    "ram":[16,32,32,16,16,32],
    "cpu_benchmark":[458,223,223,369,468,523],
    "io_read":[437,306,341,481,481,481],
    "io_write":[415,301,336,483,483,483],
    "bench_time":[36,40,39,33,30,28]
}
lotaru_spec_table = pd.DataFrame(lotaru_spec_data)

# %%
AUGUR_GU_SPEC_DATA_URL = "../augur/tool/infrastructure-profiler/profiles"
gu_nodes_id = [13,14,15,16,18]
data =[]

for node in gu_nodes_id:
    df = pd.read_csv(f"{AUGUR_GU_SPEC_DATA_URL}/gpgnode-{node}.csv")
    df = df.drop("z7b",axis=1)
    df = df.rename(columns={"sysbench":"cpu_benchmark"})
    df_reordered = df.loc[:,["node","cores","ram","cpu_benchmark","io_read","io_write","bench_time"]]
    data.append(df_reordered)

augur_gu_spec_table = pd.concat(data, ignore_index=True)
augur_gu_spec_table
# Out:
#          node  cores  ram  cpu_benchmark  io_read  io_write  bench_time
# 0  gpgnode-13     32   64         305.89     97.6      90.6  275.251000
# 1  gpgnode-14     32   64         306.01    109.0      90.9  230.926333
# 2  gpgnode-15     32   64         305.84    109.0      90.8  182.168000
# 3  gpgnode-16     32   64         306.15    109.0      91.4  197.361000
# 4  gpgnode-18     32   64         306.29    109.0      91.7  261.806000

# %%
AUGUR_HU_SPEC_URL= "../augur/tool/infrastructure-profiler/profiles"
hu_nodes = ["c40","c42","c44","c45"]
hu_data=[]
for node in hu_nodes:
    df = pd.read_csv(f"{AUGUR_HU_SPEC_URL}/hu-{node}.csv")
    df = df.drop("z7b",axis=1)
    df = df.rename(columns={"sysbench":"cpu_benchmark"})
    df_reordered = df.loc[:,["node","cores","ram","cpu_benchmark","io_read","io_write","bench_time"]]
    hu_data.append(df_reordered)

augur_hu_spec_table = pd.concat(hu_data,ignore_index=True)

augur_hu_spec_table
# Out:
#      node  cores  ram  cpu_benchmark  io_read  io_write  bench_time
# 0  hu-c40     32  256        1056.95     1362       952   23.160667
# 1  hu-c42     32  256        1049.80     1380       972   24.036333
# 2  hu-c44     32  256        1070.40      421       492   33.091667
# 3  hu-c45     32  256        1066.66      420       499   34.571667

# %%
lotaru_spec_table["source_dataset"] = "lotaru"
augur_gu_spec_table["source_dataset"]= "gu_cluster"
augur_hu_spec_table["source_dataset"] = "hu_cluster"
combined_spec_table = pd.concat([lotaru_spec_table,augur_gu_spec_table,augur_hu_spec_table], ignore_index=True)

# %%
combined_spec_table
# Out:
#           node  cores  ram  cpu_benchmark  io_read  io_write  bench_time  \
# 0        local      8   16         458.00    437.0     415.0   36.000000
# 1           a1      8   32         223.00    306.0     301.0   40.000000
# 2           a2      8   32         223.00    341.0     336.0   39.000000
# 3           n1      8   16         369.00    481.0     483.0   33.000000
# 4           n2      8   16         468.00    481.0     483.0   30.000000
# 5           c2      8   32         523.00    481.0     483.0   28.000000
# 6   gpgnode-13     32   64         305.89     97.6      90.6  275.251000
# 7   gpgnode-14     32   64         306.01    109.0      90.9  230.926333
# 8   gpgnode-15     32   64         305.84    109.0      90.8  182.168000
# 9   gpgnode-16     32   64         306.15    109.0      91.4  197.361000
# 10  gpgnode-18     32   64         306.29    109.0      91.7  261.806000
# 11      hu-c40     32  256        1056.95   1362.0     952.0   23.160667
# 12      hu-c42     32  256        1049.80   1380.0     972.0   24.036333
# 13      hu-c44     32  256        1070.40    421.0     492.0   33.091667
# 14      hu-c45     32  256        1066.66    420.0     499.0   34.571667
#
#    source_dataset
# 0          lotaru
# 1          lotaru
# 2          lotaru
# 3          lotaru
# 4          lotaru
# 5          lotaru
# 6      gu_cluster
# 7      gu_cluster
# 8      gu_cluster
# 9      gu_cluster
# 10     gu_cluster
# 11     hu_cluster
# 12     hu_cluster
# 13     hu_cluster
# 14     hu_cluster

# %%
print(augur_all.columns.tolist())
print("Augur_agg")
print(augur_agg.columns.tolist())
print(augur_all.groupby("source_cluster").size())
# Out:
# ['task_id', 'hostname', 'native_id', 'process', 'tag', 'name', 'status', 'exit', 'module', 'container', 'cpus', 'time', 'disk', 'memory', 'attempt', 'submit', 'start', 'complete', 'duration', 'realtime', 'queue', '%cpu', '%mem', 'rss', 'vmem', 'peak_rss', 'peak_vmem', 'rchar', 'wchar', 'syscr', 'syscw', 'read_bytes', 'write_bytes', 'vol_ctxt', 'inv_ctxt', 'workdir', 'scratch', 'error_action', 'cpu_model', 'task_energy_j', 'concurrent_task_count', 'source_workflow', 'source_run', 'source_cluster', 'hash']
# Augur_agg
# ['source_cluster', 'source_workflow', 'process', 'tag', 'hostname', 'runtime_s', 'peak_mem', 'energy_j', 'runtime_std', 'energy_std', 'rchar', 'cpus', 'concurrent_task_count', 'n_replicates']
# source_cluster
# gu-cluster     2715
# hu-cluster    15501
# dtype: int64

# %%
print(combined_spec_table.columns.tolist())
print(combined_spec_table["node"].tolist())
print(lotaru_df.columns.tolist())
# Out:
# ['node', 'cores', 'ram', 'cpu_benchmark', 'io_read', 'io_write', 'bench_time', 'source_dataset']
# ['local', 'a1', 'a2', 'n1', 'n2', 'c2', 'gpgnode-13', 'gpgnode-14', 'gpgnode-15', 'gpgnode-16', 'gpgnode-18', 'hu-c40', 'hu-c42', 'hu-c44', 'hu-c45']
# ['Label', 'Machine', 'Workflow', 'NumberSequences', 'Task', 'WorkflowInputSize', 'Realtime', '%cpu', 'rss', 'rchar', 'wchar', 'cpus', 'read_bytes', 'write_bytes', 'vmem', 'memory', 'peak_rss', 'TaskInputSize', 'TaskInputSizeUncompressed', 'WorkflowInputUncompressed', 'source_machine', 'source_workflow']

# %%
def normalize_node(hostname):
    if "worker" in hostname:               # hu-worker-c40 -> hu-c40
        return f"hu-{hostname.split('-')[-1]}"
    return hostname                        # gpgnode-13 stays as is

augur_agg["node"] = augur_agg["hostname"].apply(normalize_node)

missing = set(augur_agg["node"].unique()) - set(combined_spec_table["node"].unique())
print("Augur nodes with no spec match:", missing)
# Out:
# Augur nodes with no spec match: set()

# %% [markdown]
# # Creating a Unified schema by combining the Spec Table and Traces

# %%
augur_unified = augur_agg.merge(combined_spec_table, on="node", how="left")
augur_unified["source_dataset"] = "augur_" + augur_unified["source_cluster"].str.replace("-cluster", "", regex=False)

# %%
lotaru_unified = lotaru_df.rename(columns={
    "Realtime": "runtime_s",
    "peak_rss": "peak_mem",
    "source_machine": "node",
    "Task": "process",
}).copy()

lotaru_unified["energy_j"] = pd.NA
lotaru_unified["concurrent_task_count"] = pd.NA
lotaru_unified["source_dataset"] = "lotaru"
lotaru_unified = lotaru_unified.merge(combined_spec_table, on="node", how="left")

# %%
lotaru_unified = lotaru_unified.rename(columns={"source_dataset_x": "source_dataset"}).drop(columns=["source_dataset_y"])

# %%
common_cols = [
    "source_dataset", "node", "source_workflow", "process",
    "runtime_s", "peak_mem", "energy_j",
    "rchar", "cpus", "concurrent_task_count",
    "cores", "ram", "cpu_benchmark", "io_read", "io_write",
]

# %%
print("augur_unified has source_dataset:", "source_dataset" in augur_unified.columns)
print("lotaru_unified has source_dataset:", "source_dataset" in lotaru_unified.columns)
# Out:
# augur_unified has source_dataset: True
# lotaru_unified has source_dataset: False

# %%
unified = pd.concat(
    [augur_unified[common_cols], lotaru_unified[common_cols]],
    ignore_index=True
)

# %%
print(unified.shape)
print(unified.groupby("source_dataset").size())
print(unified.isna().sum())
# Out:
# (24005, 15)
# source_dataset
# augur_gu     1993
# augur_hu    11855
# lotaru      10157
# dtype: int64
# source_dataset               0
# node                         0
# source_workflow              0
# process                      0
# runtime_s                    0
# peak_mem                     3
# energy_j                 11284
# rchar                        0
# cpus                         0
# concurrent_task_count    10157
# cores                     1333
# ram                       1333
# cpu_benchmark             1333
# io_read                   1333
# io_write                  1333
# dtype: int64
#       source_dataset        node source_workflow  \
# 0           augur_gu  gpgnode-14         atacseq
# 1           augur_gu  gpgnode-16         atacseq
# 2           augur_gu  gpgnode-14         atacseq
# 3           augur_gu  gpgnode-16         atacseq
# 4           augur_gu  gpgnode-14         atacseq
# ...              ...         ...             ...
# 23999         lotaru          n2       methylseq
# 24000         lotaru          n2       methylseq
# 24001         lotaru          n2       methylseq
# 24002         lotaru          n2       methylseq
# 24003         lotaru          n2       methylseq
#
#                                                  process  runtime_s  \
# 0      NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...      588.0
# 1      NFCORE_ATACSEQ:ATACSEQ:CUSTOM_DUMPSOFTWAREVERS...     7671.0
# 2      NFCORE_ATACSEQ:ATACSEQ:FASTQ_ALIGN_BWA:BAM_SOR...     7500.0
# 3      NFCORE_ATACSEQ:ATACSEQ:FASTQ_ALIGN_BWA:BAM_SOR...     7000.0
# 4      NFCORE_ATACSEQ:ATACSEQ:FASTQ_ALIGN_BWA:BAM_SOR...    12000.0
# ...                                                  ...        ...
# 23999                                     bismark_report     1375.0
# 24000                                      bismark_align  8470013.0
# 24001                                bismark_deduplicate      177.0
# 24002                                           qualimap     2969.0
# 24003                                 bismark_methXtract    13342.0
#
#           peak_mem   energy_j         rchar  cpus concurrent_task_count  \
# 0        4816896.0    66.0825  1.023639e+06   1.0                   0.0
# 1        4634624.0   248.8336  1.023578e+06   1.0                   0.0
# 2        7157760.0   621.2081  5.521655e+08   1.0                   1.0
# 3        7192576.0    585.876  5.521656e+08   1.0                   1.0
# 4        7196672.0  1052.5113  9.327798e+08   1.0                   1.0
# ...            ...        ...           ...   ...                   ...
# 23999  100122624.0       <NA>  3.545091e+06   1.0                  <NA>
# 24000   79200256.0       <NA>  7.126226e+11   2.0                  <NA>
# 24001    3502080.0       <NA>  3.579070e+05   2.0                  <NA>
# 24002  106037248.0       <NA>  1.342586e+07   2.0                  <NA>
# 24003   24444928.0       <NA>  1.051842e+06   2.0                  <NA>
#
#        cores   ram  cpu_benchmark  io_read  io_write
# 0       32.0  64.0         306.01    109.0      90.9
# 1       32.0  64.0         306.15    109.0      91.4
# 2       32.0  64.0         306.01    109.0      90.9
# 3       32.0  64.0         306.15    109.0      91.4
# 4       32.0  64.0         306.01    109.0      90.9
# ...      ...   ...            ...      ...       ...
# 23999    8.0  16.0         468.00    481.0     483.0
# 24000    8.0  16.0         468.00    481.0     483.0
# 24001    8.0  16.0         468.00    481.0     483.0
# 24002    8.0  16.0         468.00    481.0     483.0
# 24003    8.0  16.0         468.00    481.0     483.0
#
# [24004 rows x 15 columns]

# %%
unified = unified[unified["node"] != "localRedCpu"].copy()

# %%
unified.to_csv("../Processed_data/unified_data_new.csv",index=False)

# %%
print(unified.shape)
print(unified.groupby("source_dataset").size())
print(unified.isna().sum())
# Out:
# (22672, 15)
# source_dataset
# augur_gu     1993
# augur_hu    11855
# lotaru       8824
# dtype: int64
# source_dataset              0
# node                        0
# source_workflow             0
# process                     0
# runtime_s                   0
# peak_mem                    3
# energy_j                 9951
# rchar                       0
# cpus                        0
# concurrent_task_count    8824
# cores                       0
# ram                         0
# cpu_benchmark               0
# io_read                     0
# io_write                    0
# dtype: int64
